# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mart=pd.read_csv(r'C:\Users\lenovo\Downloads\train.csv').sample(50)
mart.head()
# Out:
#       Item_ID     Item_W     Item_Type    Item_MRP Outlet_ID  Outlet_Year  \
# 34876   FDR31  13.161458  Baking Goods   68.118613    OUT013         1999
# 24773   DRF23  20.857822        Canned  143.331651    OUT046         2004
# 71832   FDD05  11.158053  Frozen Foods  263.219504    OUT013         2004
# 67527   FDZ52  16.507745   Snack Foods  132.326101    OUT018         1997
# 24981   FDY47  20.444305   Soft Drinks  131.451701    OUT046         2009
#
#       Outlet_Size Outlet_Location_Type        Sales
# 34876       Small               Tier 2  1875.970647
# 24773       Small               Tier 1  1305.157791
# 71832       Small               Tier 2  1338.292490
# 67527       Small               Tier 3  2004.888933
# 24981      Medium               Tier 3  1639.948237

# %%
mart.shape
# Out:
# (50, 9)

# %% [markdown]
# ## SCATTER PLOT

# %% [markdown]
# A diagram which shows the relationship between two variables by plotting the points/dots

# %% [markdown]
# #### 1. Create a basic scatter plot

# %%
plt.rcParams['figure.figsize']=(15,5)
sns.scatterplot(data=mart,x='Item_MRP',y='Sales')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 2. Grouping basis on a categorical variable using hue

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',hue='Outlet_Size')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 3. Grouping basis on a categorical variable using STYLE and Styling markers as well

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',hue='Outlet_Size',style='Outlet_Size')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',style='Outlet_Size',markers={"Small":"^","Medium":"*","High":"o"})
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 4. Grouping basis on a categorical variable using HUE & STYLE together

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',hue='Outlet_Location_Type',style='Outlet_Size')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 5. Grouping basis on numeric variable using HUE and use PALETTE

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',hue='Outlet_Size',palette='Purples')
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 6. Grouping basis on a numeric variable using HUE & SIZE

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales'
               ,hue='Outlet_Size'
               ,size='Outlet_Location_Type'
               ,sizes=(20,200)
               ,legend='full'
               ,palette='cubehelix'
                )
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %%
# it's better to use hue and size with same feature
sns.scatterplot(data=mart,x='Item_MRP',y='Sales'
               ,hue='Outlet_Size'
               ,size='Outlet_Size'
               ,sizes=(20,200)
               ,legend='full'
               ,palette='spring'
                )
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# #### 7. Change the Marker Size using S

# %%
sns.scatterplot(data=mart,x='Item_MRP',y='Sales',s=500)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Sales'>

# %% [markdown]
# ## LINE PLOT

# %% [markdown]
# Shoes the relation between two variables  ||   Majorly used in time series analysis
#
# Showcases how the value of variable changes over the time

# %%
mart.head()
# Out:
#       Item_ID     Item_W     Item_Type    Item_MRP Outlet_ID  Outlet_Year  \
# 34876   FDR31  13.161458  Baking Goods   68.118613    OUT013         1999
# 24773   DRF23  20.857822        Canned  143.331651    OUT046         2004
# 71832   FDD05  11.158053  Frozen Foods  263.219504    OUT013         2004
# 67527   FDZ52  16.507745   Snack Foods  132.326101    OUT018         1997
# 24981   FDY47  20.444305   Soft Drinks  131.451701    OUT046         2009
#
#       Outlet_Size Outlet_Location_Type        Sales
# 34876       Small               Tier 2  1875.970647
# 24773       Small               Tier 1  1305.157791
# 71832       Small               Tier 2  1338.292490
# 67527       Small               Tier 3  2004.888933
# 24981      Medium               Tier 3  1639.948237

# %% [markdown]
# #### 1. Create BASIC Line PLot

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None)
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### 2. Test with different confidence interval and with different number of Bootstrapping

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci="sd") #sd --> standard deviation
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',n_boot=2) #n_boot default is 1000
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### 3. Grouping using HUE and use different Palettes

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None,hue='Outlet_Size',palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### 4. Grouping using style,use different Markers and Dashes

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None,style='Outlet_Size',markers=True)
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None,style='Outlet_Size',markers=True,dashes=False)
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### 5. Grouping using size

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None,size='Outlet_Size',color='Purple',sizes=(0.5,5))
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# #### 6. Use different semantic styling parameters on same different variables

# %%
sns.lineplot(data=mart,x='Outlet_Year',y='Sales',ci=None,hue='Outlet_Size',style='Outlet_Size',markers=True)
# Out:
# <AxesSubplot:xlabel='Outlet_Year', ylabel='Sales'>

# %% [markdown]
# ## REL PLOT

# %%
mart.head()
# Out:
#       Item_ID     Item_W     Item_Type    Item_MRP Outlet_ID  Outlet_Year  \
# 34876   FDR31  13.161458  Baking Goods   68.118613    OUT013         1999
# 24773   DRF23  20.857822        Canned  143.331651    OUT046         2004
# 71832   FDD05  11.158053  Frozen Foods  263.219504    OUT013         2004
# 67527   FDZ52  16.507745   Snack Foods  132.326101    OUT018         1997
# 24981   FDY47  20.444305   Soft Drinks  131.451701    OUT046         2009
#
#       Outlet_Size Outlet_Location_Type        Sales
# 34876       Small               Tier 2  1875.970647
# 24773       Small               Tier 1  1305.157791
# 71832       Small               Tier 2  1338.292490
# 67527       Small               Tier 3  2004.888933
# 24981      Medium               Tier 3  1639.948237

# %% [markdown]
# #### 1. First Rel Plot

# %%
sns.relplot(x='Outlet_Year',y='Sales',data=mart,s=100)
sns.relplot(x='Outlet_Year',y='Sales',data=mart,kind='line',ci=None)

# %%
sns.relplot(x='Outlet_Year',y='Sales',data=mart,s=100,hue='Outlet_Size')

# %%
sns.relplot(x='Outlet_Year',y='Sales',data=mart,s=100,hue='Outlet_Size',col='Item_Type')

# %% [markdown]
# since there are 15 unique values it showing in one row. So we use col_wrap to make it more organised

# %%
sns.relplot(x='Outlet_Year',y='Sales',data=mart,s=100,hue='Outlet_Size',col='Item_Type',col_wrap=5)

# %%
sns.relplot(x='Outlet_Year',y='Sales',data=mart,s=100,hue='Outlet_Size',col='Outlet_Size',row='Outlet_Location_Type')
